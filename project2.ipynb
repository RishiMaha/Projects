# %% [markdown]
# # Section 1: Dataset

# %% [markdown]
# I chose a dataset that contains all professional tennis match outcomes on the mens circuit from 2013 to 2023. I chose this data set because I would like to analyze and see how the type of court surface affects player performance. I would also like to see what kinds of trends I see in terms of the players who win the most and other aspects. This is meaningful to me because I am a tennis player myself and love to watch the sport. This data analysis gives me the ability to see the game more from a numbers perspective. I found this dataset by searching ATP tour match data on kaggle.

# %%
# Import pandas as pd
import pandas as pd

# Load in dataset into variable 'df'
df = pd.read_csv("atp_tennis.csv")
df
# Out:
#                    Tournament        Date        Series    Court Surface  \
# 0      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 1      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 2      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 3      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 4      Brisbane International  2013-01-01        ATP250  Outdoor    Hard
# ...                       ...         ...           ...      ...     ...
# 25357              Miami Open  2023-03-30  Masters 1000  Outdoor    Hard
# 25358              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25359              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25360              Miami Open  2023-04-01  Masters 1000  Outdoor    Hard
# 25361              Miami Open  2023-04-02  Masters 1000  Outdoor    Hard
#
#                Round  Best of      Player_1      Player_2        Winner  \
# ...

# %% [markdown]
# # Section 2: Exploratory Data Analysis:

# %% [markdown]
# There are many descriptive statistics that can help give an overview of the data. The first descriptive statistic that can help give me a broad overview is the size of the data set just to see how large the entire dataset is. The next descriptive statistic that can help me is to find the number of unique values in the dataset which will tell me how unique values each category has (such as the number of players or tournaments). Other descriptive statistics such as the mean, standard deviation, and more can give a good overview of the data.

# %%
# Size of the dataset
size = df.size
print("Size of the dataset:", size)

# Count the number of unique values
df_uqu = df.nunique()
df_uqu
# Out:
# Size of the dataset: 431154
# Tournament     141
# Date          2769
# Series           5
# Court            2
# Surface          3
# Round            8
# Best of          3
# Player_1       668
# Player_2       664
# Winner         527
# Rank_1         603
# Rank_2         581
# Pts_1         2756
# Pts_2         2760
# Odd_1          104
# Odd_2          102
# score         4286
# dtype: int64

# %%
# Descriptive statistics for numerical categories
df_num = df[['Rank_1', 'Rank_2', 'Pts_1', 'Pts_2', 'Odd_1', 'Odd_2']].describe()
df_num
# Out:
#              Rank_1        Rank_2         Pts_1         Pts_2         Odd_1  \
# count  25362.000000  25362.000000  25362.000000  25362.000000  25362.000000
# mean      72.601136     71.944720   1575.219107   1564.255264      2.685540
# std       93.999548     89.268571   1931.790990   1905.969182      2.817076
# min        1.000000      1.000000      1.000000      1.000000      0.967000
# 25%       24.000000     24.000000    640.000000    636.000000      1.400000
# 50%       52.000000     52.000000    937.000000    930.000000      1.830000
# 75%       89.000000     90.000000   1641.000000   1618.750000      2.750000
# max     2146.000000   2159.000000  16950.000000  16950.000000     67.000000
#
#               Odd_2
# count  25362.000000
# mean       2.710894
# std        2.888063
# min        0.967000
# 25%        1.400000
# 50%        1.830000
# 75%        2.750000
# max       51.000000

# %%
# Create a new Data frame where the type of court surface is only hard court
df_hard = df[df.Surface == "Hard"]
df_hard
# Out:
#                    Tournament        Date        Series    Court Surface  \
# 0      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 1      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 2      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 3      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 4      Brisbane International  2013-01-01        ATP250  Outdoor    Hard
# ...                       ...         ...           ...      ...     ...
# 25357              Miami Open  2023-03-30  Masters 1000  Outdoor    Hard
# 25358              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25359              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25360              Miami Open  2023-04-01  Masters 1000  Outdoor    Hard
# 25361              Miami Open  2023-04-02  Masters 1000  Outdoor    Hard
#
#                Round  Best of      Player_1      Player_2        Winner  \
# ...

# %%
# Create a new Data frame where the type of court surface is only clay court
df_clay = df[df.Surface == "Clay"]
df_clay
# Out:
#        Tournament        Date  Series    Court Surface          Round  \
# 292      VTR Open  2013-02-04  ATP250  Outdoor    Clay      1st Round
# 293      VTR Open  2013-02-04  ATP250  Outdoor    Clay      1st Round
# 294      VTR Open  2013-02-05  ATP250  Outdoor    Clay      1st Round
# 295      VTR Open  2013-02-05  ATP250  Outdoor    Clay      1st Round
# 296      VTR Open  2013-02-05  ATP250  Outdoor    Clay      1st Round
# ...           ...         ...     ...      ...     ...            ...
# 25167  Chile Open  2023-03-03  ATP250   Indoor    Clay  Quarterfinals
# 25168  Chile Open  2023-03-04  ATP250   Indoor    Clay  Quarterfinals
# 25169  Chile Open  2023-03-04  ATP250   Indoor    Clay     Semifinals
# 25170  Chile Open  2023-03-04  ATP250   Indoor    Clay     Semifinals
# 25171  Chile Open  2023-03-05  ATP250   Indoor    Clay      The Final
#
#        Best of            Player_1       Player_2         Winner  Rank_1  \
# ...

# %%
# Create a new Data frame where the type of court surface is only grass court
df_grass = df[df.Surface == "Grass"]
df_grass
# Out:
#                        Tournament        Date  Series    Court Surface  \
# 1328             Gerry Weber Open  2013-06-10  ATP250  Outdoor   Grass
# 1329             Gerry Weber Open  2013-06-10  ATP250  Outdoor   Grass
# 1330             Gerry Weber Open  2013-06-10  ATP250  Outdoor   Grass
# 1331             Gerry Weber Open  2013-06-10  ATP250  Outdoor   Grass
# 1332             Gerry Weber Open  2013-06-11  ATP250  Outdoor   Grass
# ...                           ...         ...     ...      ...     ...
# 23640  Hall of Fame Championships  2022-07-15  ATP250  Outdoor   Grass
# 23641  Hall of Fame Championships  2022-07-15  ATP250  Outdoor   Grass
# 23642  Hall of Fame Championships  2022-07-16  ATP250  Outdoor   Grass
# 23643  Hall of Fame Championships  2022-07-16  ATP250  Outdoor   Grass
# 23644  Hall of Fame Championships  2022-07-17  ATP250  Outdoor   Grass
#
#                Round  Best of          Player_1    Player_2      Winner  \
# ...

# %%
# Seeing how many wins each player has
df['Winner'].value_counts()
# Out:
# Winner
# Djokovic N.      552
# Nadal R.         467
# Federer R.       361
# Cilic M.         331
# Murray A.        324
#                 ...
# Benchetrit E.      1
# Puetz T.           1
# Sorensen L.        1
# Davydenko P.       1
# Wu T.L.            1
# Name: count, Length: 527, dtype: int64

# %% [markdown]
# # Section 3: Exploratory Data Visualization

# %%
# Visualization to see how many matches took place on each surface to see the most popular type of surface
import matplotlib.pyplot as plt

df["Surface"].hist(bins = 5, edgecolor = 'black')
plt.title('Number of Matches Per Surface')
plt.xlabel('Surface Type')
plt.ylabel('Match Count')
plt.show()

# %% [markdown]
# This plot is a visual representation showing the distribution of matches by type of surface. The plot is able to illustrate how many matches from the data set were played on each type of surface. It is able to give an understanding of which surfaces are most commonly played on in the mens tour.

# %%
# Filter the 'round column' to show only the finals
finals = df[df['Round'] == 'The Final']

# Count final appearances for each player
finalists = pd.concat([finals['Player_1'], finals['Player_2']])
final_appearances = finalists.value_counts()

# Get the top 10 players with the most final appearances
top_finalists = final_appearances.head(10)


plt.figure(figsize=(10, 6))
top_finalists.plot(kind='bar', color='steelblue')
plt.title('Top 10 Players with Most Final Appearances Since 2013')
plt.xlabel('Player Names')
plt.ylabel('Number of Final Appearances')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This graph shows the 10 players with the most final round appearances since 2013. It shows which players have been dominating the game and successfully competing in tournaments since 2013.

# %% [markdown]
# # Section 4: Data Science

# %% [markdown]
# ##### How often does the higher ranked player end up winning the match?
# I will first clean the data by adding two new columns. One column will be a numerical representaiton of the player with the higher ranking while the other column will be a numerical representation of the player who won the match. This will make it easier to compare the two values.
# After cleaning the data, I will find the correlation between the two columns and then calculate the percentage of when the higher ranked player has won the match.

# %%
# Adding another winner column to represent the winner as a number instead of a string
def numeric_winner(row):
    if row['Player_1'] == row['Winner']:
        return 1
    else:
        return 2
df["Num_Winner"] = df.apply(numeric_winner, axis = 1)

# Adding a column to show which player has the higher ranking
def rank(row):
    if row['Rank_1'] < row['Rank_2']:
        return 1
    else:
        return 2
df["Higher_Rank"] = df.apply(rank, axis = 1)
df
# Out:
#                    Tournament        Date        Series    Court Surface  \
# 0      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 1      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 2      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 3      Brisbane International  2012-12-31        ATP250  Outdoor    Hard
# 4      Brisbane International  2013-01-01        ATP250  Outdoor    Hard
# ...                       ...         ...           ...      ...     ...
# 25357              Miami Open  2023-03-30  Masters 1000  Outdoor    Hard
# 25358              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25359              Miami Open  2023-03-31  Masters 1000  Outdoor    Hard
# 25360              Miami Open  2023-04-01  Masters 1000  Outdoor    Hard
# 25361              Miami Open  2023-04-02  Masters 1000  Outdoor    Hard
#
#                Round  Best of      Player_1      Player_2        Winner  \
# ...

# %%
# Rank comparison
rank_comparison = df["Higher_Rank"].corr(df["Num_Winner"])
print("\nCorrelation between the higher ranked player and the player who won", rank_comparison)
df_same = df[df.Num_Winner == df.Higher_Rank]
prob = len(df_same) / len(df)
print("\nProbability that the higher ranked player was also the winner", prob)
# Out:
# Correlation between the higher ranked player and the player who won 0.2972237936421684
#
# Probability that the higher ranked player was also the winner 0.648608153931078

# %% [markdown]
# # Section 5: Overall Summary

# %% [markdown]
# For this data science project I decided to analyze a dataset containing every tennis match played on the ATP professional mens circuit from 2013 to 2023. I chose this specific dataset because I wanted to see any trends in the data and how the numbers stack up over the last 10 years. After importing the dataset I wanted to get a good overview of the data which is why I used various descriptive statistics to breakdown the data. I then proceded to create two data visualizations that would help me understand the data a little bit better. The first visualization is a graph showing the number of matches played on each surface, and the second visualization shows the top 10 players with the most finals appearances. This gives me an indication of which surface is most popular and which players have been dominating the game for the last 10 years. Lastly, I came up with two questions: how often does the higher ranked player end up winning the match and can the winner of a match be predicted based on which payer has the higher ranking?. I found how often the higher ranked player ended up winning by creating numerical columns to help find the probability and correlation between the two variables. To predict the match winner, I used a simple linear regression model and trained it on 80% of the dataset with the remaining 20% for testing.
